# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
matplotlib.use()

# %%
# %matplotlib notebook

# %%
In [13]: data = np.arange(10)

In [14]: data

In [15]: plt.plot(data)
plt.show()

# %%
fig = plt.figure(num = 1,figsize = (6,8),dpi = 80)

# %%
fig.set_edgecolor

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot([2,3],[4,5])

# %%
_ = ax1.hist(np.random.randn(100), bins=20, color='r', alpha=0.3)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig, axes = plt.subplots(2, 3)
#返回画布及子图数组
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000006CCE898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000006C7C1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000006DCE828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000006FD3DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000070044E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000702DB00>]],
#       dtype=object)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
In [33]: data = np.random.randn(30).cumsum()

In [34]: plt.plot(data, 'k--', label='Default')

In [35]: plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
#Out[35]: [<matplotlib.lines.Line2D at 0x7fb624d869e8>]

In [36]: plt.legend(loc='best')

# %%
In [37]: fig = plt.figure()

In [38]: ax = fig.add_subplot(1, 1, 1)

In [39]: ax.plot(np.random.randn(1000).cumsum())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.set_xticks([x*50 for x in range(20)])
# Out:
# [<matplotlib.axis.XTick at 0x141a6f28>,
#  <matplotlib.axis.XTick at 0x1414a6d8>,
#  <matplotlib.axis.XTick at 0x13d7f860>,
#  <matplotlib.axis.XTick at 0x141d95c0>,
#  <matplotlib.axis.XTick at 0x141d9da0>,
#  <matplotlib.axis.XTick at 0x141e32b0>,
#  <matplotlib.axis.XTick at 0x141e3780>,
#  <matplotlib.axis.XTick at 0x141d94e0>,
#  <matplotlib.axis.XTick at 0x141531d0>,
#  <matplotlib.axis.XTick at 0x144cf0b8>,
#  <matplotlib.axis.XTick at 0x144cf748>,
#  <matplotlib.axis.XTick at 0x144cfc18>,
#  <matplotlib.axis.XTick at 0x144d3160>,
#  <matplotlib.axis.XTick at 0x144d35f8>,
#  <matplotlib.axis.XTick at 0x144d3ac8>,
#  <matplotlib.axis.XTick at 0x144d3e80>,
#  <matplotlib.axis.XTick at 0x144d94a8>,
#  <matplotlib.axis.XTick at 0x144d3a90>,
#  <matplotlib.axis.XTick at 0x144cf710>,
#  <matplotlib.axis.XTick at 0x144d98d0>]

# %%
ax
